# %% [markdown]
# # Домашнее задание 1 (25 + 30 + 27 + 30 = 112 pts)

# %% [markdown]
# ## Задача 1 (25 pts)
#
# - (3 pts) Докажите, что $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$.
# - (3 pts) Покажите, что для любых $m, n$ и $k \le \min(m, n)$ существует $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, такая что $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$.
# - (3 pts) Докажите, что $\| A B \|_F \le \| A \|_2 \| B \|_F$.
# - (2 pts) Докажите, что для любой эрмитовой матрицы сингулярные числа совпадают с абсолютными значениями собственных значений. Выполнено ли это для произвольной матрицы? Докажите, что выполнено или приведите контрпример.
#
# - (3 pts) Найдите аналитически скелетное разложение матрицы $\begin{pmatrix} 1 & -2 & 5 \\ 5 & 3 & 9 \\ 3 & 7 & -1\end{pmatrix}$.
#
# - (1 pts) Покажите, что если матрица $A$ обратима, то $\|A^{-1}\|_F \geq \frac{\sqrt{n}}{\|A\|_F}$
#
# - (3 pts) Рассмотрим матрицу $A = \begin{bmatrix} I & a \\ a^{\top} & 0 \end{bmatrix}$. Когда она является обратимой? Пусть она обратима, тогда найдите выражение для $A^{-1}$
#
# - (3 pts) Пусть матрица $A$ ортогональна и все её элементы неотрицательны, то есть $a_{ij} \geq 0$. Покажите, что тогда $A$ есть матрица перестановки
#
# - (2 pts) Пусть матрица $A \in \mathbb{C}^{n \times n}$ и её сингулярное разложение $A = U\Sigma V^*$. Найдите спектральное разложение (разложение по собственным векторам) матрицы $\begin{bmatrix} 0 & A^* \\ A & 0 \end{bmatrix}$ размера $2n \times 2n$
#
# - (2 pts) Рассмотрим матрицу $\begin{bmatrix} A_1 \\ A_2 \end{bmatrix}$, где матрица $A_1$ невырождена и размера $n \times n$, а матрица $A_2$ произвольная размера $(m - n) \times n$. Докажите, что $\|A^{\dagger}\|_2 \leq \|A^{-1}_1\|_2$

# %% [markdown]
# ### Решение
# - Доказательство: $\| A \|_F^2 = trace(A^*A) = \sum_{i}\sigma_i^2 \le n\sigma_{max}^2 = n\|A\|_s^2$
# - $\|A\|_F = \sqrt{\sum_j\lambda_j(A*A)}$ Но тогда для того, чтобы $\sqrt{\sum_j\lambda_j(A*A)} = \sqrt{rank(A)\lambda_{max}(A*A)}$ необходимо и достаточно, чтобы:
# $rank(A) = k$ и
# $\sum_j\lambda_j=k\lambda_{max}(A*A)$ $\Rightarrow$ $\lambda_i=\lambda_j \forall i,j = 1\dots k$. Но т.к. $A\in \mathbb{R}^{m \times n}$, то $k\leqslant min(m,n) \forall m,n$
# - Предположим, что неравенство верно, тогда : $\sum_i\|Ab_i\|_2^2 \leqslant max\frac{\|Ax\|_2^2}{\|x\|_2^2}(\sum_i \|b_i\|_2^2)$ , где $b_i$ столбцы матрицы $B$.
# $\sum_i \frac{\|Ab_i\|_2^2}{\|b_i\|_2^2} \|b_i\|_2^2 \leqslant max\frac{\|Ax\|_2^2}{\|x\|_2^2}(\sum_i \|b_i\|_2^2)$ перенеся в левую часть, получим $\sum_i \|b_i\|_2^2(\frac{\|Ab_i\|_2^2}{\|b_i\|_2^2} - max\frac{\|Ax\|_2^2}{\|x\|_2^2}) \leqslant 0$ что верно. Значит исходное неравенство верно.
# - Если $A$ эрмитова, то $A = Q\Lambda Q* = Q|\Lambda|sign(\Lambda)Q*$, но $sign(A)Q*$-  унитарна $\Rightarrow$ это SVD разложение $\Rightarrow$ верно. В общем случае это утверждение неверно, например, для матрицы $\begin{pmatrix}5 & -1\\ 0 & 5\end{pmatrix}$
# - Решение: $\begin{pmatrix} 1 & -2 & 5 \\ 5 & 3 & 9 \\ 3 & 7 & -1\end{pmatrix}$. Применим метод Гаусса $\begin{pmatrix} 1 & -2 & 5 \\ 0 & 13 & -16 \\ 0 & 13 & -16 \end{pmatrix}$, следовательно матрица $\mathbb{С}$  $\begin{pmatrix} 1 & -2 & 5 \\ 5 & 3 & 9 \end{pmatrix}$, найдем псевдообратную матрицу $\mathbb{C^{+}}$, которая $\begin{pmatrix} -0.06935 & 0.07001 \\ -0.23910 &  0.11756 \\ 0.11822 & 0.0330\end{pmatrix}$. Матрица $\mathbb{B}=A\cdot\mathbb{C^{+}}=\begin{pmatrix} 1 & 0 \\ 0 & 1 \\ -2 & 1 \end{pmatrix}$. Скелетное разложение $\mathbb{A}=\mathbb{B}\cdot\mathbb{C}=\begin{pmatrix} 1 & 0 \\ 0 & 1 \\ -2 & 1 \end{pmatrix}{\cdot}\begin{pmatrix} 1 & -2 & 5 \\ 5 & 3 & 9 \end{pmatrix}$
# - Доказательство: Воспользуемся свойством субмультипликативности нормы Фробениуса $\|I\|_F\le\|A\|_F\|A^{-1}\|_F \Rightarrow \sqrt{n}\le\|A\|_F\|A^{-1}\|_F$
# - Если $a\ne0$, то $\mathbb{det}A=-a^{\top}{\cdot}a$, следовательно матрица $A^{-1}$ существует. Имеем $\begin{bmatrix} I & a  \\ a^{\top} & 0 \end{bmatrix}\begin{bmatrix} b_1 & b_2 \\ b_3 & b_4 \end{bmatrix}=I$, перемножим матрицы и получим систему уравнений, которая даст
# $b_1 = 0, b_2 = \frac{a}{a^{\top}a}, b_3 =\frac{a^{\top}}{a^{\top}a}, b_4 = - \frac{I}{a^{\top}a}$
#
# - Доказательство: Зафиксируем строку $i$ матрицы $\mathbb{A}$, предположим, что в строке два или более положительных элемента, тогда возьмем любые два элемента $a_{i,j_1}, a_{i,j_2}$. В матрице $\mathbb{A}$ строки и столбцы равноценны, значит в матрице $\mathbb{A}{\cdot}\mathbb{A^{\top}}=\mathbb{I}$ в позиции $(j_1,j_2)$ стоит число большее 0, что невозможно. Отсюда следует, что в каждой строке есть только одно положительный элемент $a_{i,j}$, который должен быть равен $1$. Значит матрица составлена так, что в каждой строке стоит $1$ на своей позиции и позиции не пересекаются, то есть матрица является перестановочной матрицей.
#
# - $\begin{bmatrix} 0 & A^* \\ A & 0 \end{bmatrix}$ = $C^{-1}$ $\begin{bmatrix} \Sigma & 0 \\ 0 & -\Sigma \end{bmatrix}C$ , где
# $C^{-1}_{2n*2n}$ = $\begin{bmatrix} U^* e_{1} & U^* e_{1} & U^* e_{2} & U^* e_{2} & ... & U^* e_{n} & U^* e_{n} \\ V^* e_{1} & -V^* e_{1} & V^* e_{2} & -V^* e_{2} & ... & V^* e_{n} & -V^* e_{n}\end{bmatrix}$,
# а $e_k$ - единичный вектор с 1 на позиции k и остальными нулями

# %% [markdown]
# ## Задача 2. LU разложение (30 pts)

# %% [markdown]
# ### 1. LU разложение для ленточных матриц (7 pts)
#
# Сложность вычисления LU разложения для матрицы размера $n\times n$ – $\mathcal{O}(n^3)$.
# Существенного уменьшения сложности можно добиться для матриц определённой структуры, например разреженных.
# В этой задаче рассмотрим специальный класс разреженных матриц, а именно ленточные матрицы с шириной ленты 3 и 5, которые называются трёхдиагональными и пятидиагональными, соответственно.
#
# - (5 pts) Реализуйте функцию ```band_lu(diag_broadcast, n)```, которая вычисляет LU разложение для пяти- или трёхдиагональной матрицы, на основании данных значений на диагоналях. Предполагается, что на главной диагонали фактора ```L``` стоят 1.
# Например, входные параметры ```(diag_broadcast = [3,-5,4], n = 4)``` означают, что необходимо найти LU разложение для трёхдиагональной матрицы вида:
#
# $$A = \begin{pmatrix}
# -5 & 4 & 0 & 0\\
# 3 & -5 & 4 & 0 \\
# 0 & 3 & -5 & 4 \\
# 0 & 0 & 3 & -5 \\
# \end{pmatrix}.$$
#
# Функция должна возвращать двумерные NumPy массивы ```L``` и ```U```, в которых хранятся диагонали факторов. Например, ```L[0]``` содержит первую под-диагональ (поскольку на главной диагонали стоят 1, то её возвращать не нужно), ```L[1]``` – вторую под-диагональ и т.д.), аналогично для $U$ (```U[:,0]``` содержит главную диагональ, ```U[:,1]``` содержит первую над-диагональ и т.д.). Прототип функции приведён ниже и не должен меняться.
# - (2 pts) Сравните время вычисления LU разложения с помощью стандартной функции в ```scipy```, которая ничего не знает о структуре матрицы, и вашей реализацией LU разложения для ленточной матрицы. Объясните результат. Постройте график зависимости времени факторизации от размерности факторизуемой матрицы. Выберите интервал размерностей факторизуемой матрицы так, чтобы динамика зависимости времени от размерности была различима. При необходимости используйте логарифмический масштаб по оси ```y```.

# %%
# INPUT : diag_broadcast - list of diagonals value to broadcast, length equal to 3 or 5; n - integer, band matrix shape.
# OUTPUT : L - 2D np.ndarray, L.shape[0] depends on bandwidth, L.shape[1] = n-1, do not store main diagonal, where all ones;                  add zeros to the right side of rows to handle with changing length of diagonals.
#          U - 2D np.ndarray, U.shape[0] = n, U.shape[1] depends on bandwidth;
#              add zeros to the bottom of columns to handle with changing length of diagonals.
def band_lu(diag_broadcast, n):
    d = len(diag_broadcast)

    D = np.array([ np.full((n,),D) for D in diag_broadcast ]) 
    U = np.zeros((n,int(d/2+1)))                 
    L = np.zeros((int(d/2+0),n-1))                 

    U[0,:] = D[int(d/2):,0]
    L[:,0] = D[:int(d/2),0]/D[int(d/2),0]

    for i in range(1,n-1):
        for j in range(int(d/2)+1):
            U[i,j] = D[j+int(d/2),i]
        for j in range(int(d/2+0)):
            L[j,i] = D[j,i]
    U[n-1,:] = D[int(d/2):,n-1]
    return L, U

# %% [markdown]
# Функция для создания диагональных матриц:

# %%
from scipy.sparse import diags
import numpy as np

def make_diagonal_matrix(elements, n):
    m = len(elements)
    diagonals = []
    for k in range(m):
        if k > m / 2:
            j = -(k - int(m / 2))
        else:
            j = k - int(m / 2)
        d = [elements[k] for i in range(n+j)]
        diagonals.append(d)
    mask = np.array(range(m)) - int(m/2)
    return diags(diagonals,  mask).toarray()

# %%
make_diagonal_matrix([1,3,-2], 5)
# Out:
# array([[ 3., -2.,  0.,  0.,  0.],
#        [ 1.,  3., -2.,  0.,  0.],
#        [ 0.,  1.,  3., -2.,  0.],
#        [ 0.,  0.,  1.,  3., -2.],
#        [ 0.,  0.,  0.,  1.,  3.]])

# %% [markdown]
# #### Сравнение времени

# %%
import timeit
import functools
from scipy.linalg import lu_factor
from random import randint
import matplotlib.pyplot as plt
# %matplotlib inline

numbers = [10, 100,300, 1000, 3000, 5000]
t1 = []
t2 = []
for n in numbers:
    print(n)
    elements = [randint(-1000, 1000), randint(-1000, 1000), randint(-1000, 1000)]
    t = timeit.Timer(functools.partial(band_lu, elements, n))
    t1.append(t.timeit(30))
    A =  make_diagonal_matrix(elements, n)
    t = timeit.Timer(functools.partial(lu_factor, A))
    t2.append(t.timeit(30))
plt.plot(numbers, t1, label = 'my_LU size 3')
plt.plot(numbers, t2, label = 'scipy_LU size 3')
plt.xlabel("Matrix size")
plt.ylabel('Time elapsed')
plt.yscale("log")
plt.legend()
plt.show()

t3 = []
t4 = []
for n in numbers:
    print(n)
    a = [randint(-1000, 1000), randint(-1000, 1000), randint(-1000, 1000),randint(-1000, 1000), randint(-1000, 1000)]
    t = timeit.Timer(functools.partial(band_lu, elements, n))
    t3.append(t.timeit(30))
    A = make_diagonal_matrix(elements, n)
    t = timeit.Timer(functools.partial(lu_factor, A))
    t4.append(t.timeit(30))
plt.plot(numbers, t3, label = 'my_LU size 5')
plt.plot(numbers, t4, label = 'scipy_LU size 3')
plt.xlabel("Matrix size")
plt.ylabel('Time elapsed')
plt.yscale("log")
plt.legend()
plt.show()
# Out:
# 10
# 100
# 300
# 1000
# 3000
# /usr/lib/python3.7/timeit.py:6: LinAlgWarning: Diagonal number 3000 is exactly zero. Singular matrix.
#   times.  See also Tim Peters' introduction to the Algorithms chapter in
# 5000
# 10
# 100
# 300
# 1000
# 3000
# 5000

# %% [markdown]
# ### 2. Устойчивость LU разложения (13 pts)
#
# Рассмотрим матрицу вида
# $A = \begin{pmatrix}
# \varepsilon & 1 & 0\\
# 1 & 1 & 1 \\
# 0 & 1 & 1
# \end{pmatrix}.$
# * (7 pts) Реализуйте алгоритм вычисления LU разложения без выбора ведущего элемента и с выбором (выберете один из способов, рассмотренных на лекции).
# * (3 pts) Покажите, что ваши реализации работают корректно и согласуются с теорией, то есть вычислите выражение $\| A - PLUQ\|_F$ для тестовых примеров (один их них приведён выше)
# * (3 pts) Объясните, почему алгоритм вычисления LU разложения без выбора ведущего элемента плохо аппроксимирует факторы $L$ и $U$ для $|\varepsilon|\ll 1$ в приведённой выше матрице в машинной арифметике? Покажите это явным вычислением.

# %% [markdown]
# #### Разложение без выбора ведущего элемента

# %%
  def lu_decomposition(A):
    n = A.shape[0]
    U = A.copy()
    L = np.eye(n, dtype=np.double)
    for i in range(n):    
        f = U[i+1:, i] / U[i, i]
        L[i+1:, i] = f
        U[i+1:] = U[i+1:] - f[:, np.newaxis] * U[i]
    return L, U

# %%
## Проверка
from numpy import linalg as LA

for e in [0.1, 0.001, 1e-6, 1e-10, 1e-16, 1e-20]:
  A = np.array([[e, 1, 0], [1, 1, 1], [0, 1, 1]])
  L ,U = lu_decomposition(A)

  print(f'|A-LU| for eps ={e} : ', LA.norm(A - np.dot(L,U)))
# Out:
# |A-LU| for eps =0.1 :  0.0
# |A-LU| for eps =0.001 :  0.0
# |A-LU| for eps =1e-06 :  0.0
# |A-LU| for eps =1e-10 :  0.0
# |A-LU| for eps =1e-16 :  1.0
# |A-LU| for eps =1e-20 :  1.0

# %% [markdown]
# #### Разложение с выбором ведущего элемента

# %%
def pivoting_matrix(M):
    m = len(M)
                                                                                                                                                                                          
    id_mat = [[float(i ==j) for i in range(m)] for j in range(m)]
                                                                                                                                                                                       
    for j in range(m):
        row = max(range(j, m), key=lambda i: abs(M[i][j]))
        if j != row:                                                                                                                                                                                                                     
            id_mat[j], id_mat[row] = id_mat[row], id_mat[j]
    return id_mat

def lu_decomposition_pivot(A):
    n = len(A)
                                                                                                                                                                                                                
    L = [[0.0] * n for i in range(n)]
    U = [[0.0] * n for i in range(n)]
                                                                                                                                                                                    
    P = pivoting_matrix(A)
    PA = np.dot(P,A)
                                                                                                                                                                                                                  
    for j in range(n):                                                                                                                                                                                                
        L[j][j] = 1.0                                                                                                                                                                                   
        for i in range(j+1):
            s1 = sum(U[k][j] * L[i][k] for k in range(i))
            U[i][j] = PA[i][j] - s1                                                                                                                                                              
        for i in range(j, n):
            s2 = sum(U[k][j] * L[i][k] for k in range(j))
            L[i][j] = (PA[i][j] - s2) / U[j][j]

    return (P, L, U)

# %%
## Проверка
from numpy import linalg as LA

for e in [0.1, 0.001, 1e-6, 1e-10, 1e-16, 1e-20]:
  A = np.array([[e, 1, 0], [1, 1, 1], [0, 1, 1]])
  P, L ,U = lu_decomposition_pivot(A)

  print(f'|A-PLU| for eps ={e} : ', LA.norm(A - np.dot(np.dot(P,L),U)))
# Out:
# |A-PLU| for eps =0.1 :  0.0
# |A-PLU| for eps =0.001 :  0.0
# |A-PLU| for eps =1e-06 :  0.0
# |A-PLU| for eps =1e-10 :  0.0
# |A-PLU| for eps =1e-16 :  1.1102230246251565e-16
# |A-PLU| for eps =1e-20 :  0.0

# %% [markdown]
# Если $|\varepsilon|\ll 1$ то, в случае не использования ведущего элемента, будут вычисления чисел $\frac{1}{\varepsilon}$ , и дальше они будут складываться с другими числами несколько раз. Из-за реализации чисел с плавающей точкой ошибка вычислений сумм по строкам будет накапливаться и близко посчитать разложение у нас не получится.

# %% [markdown]
# ### 3. Блочное LU разложение (10 pts)
#
# Пусть $A = \begin{bmatrix} A_{11} & A_{12} \\ A_{21} & A_{22} \end{bmatrix}$ – блочная матрица. Необходимо решить систему линейных уравнений вида
#
# $$
#      \begin{bmatrix} A_{11} & A_{12} \\ A_{21} & A_{22} \end{bmatrix} \begin{bmatrix} u_1 \\ u_2 \end{bmatrix} = \begin{bmatrix} f_1 \\ f_2 \end{bmatrix}.
# $$
#
# * (2 pts) Используя процедуру блочного исключения, найдите матрицу $S$ и правую часть $\hat{f_2}$ такую что $u_2$ может быть найден из системы $S u_2 = \hat{f_2}$. Матрица $S$ называется <font color='red'> дополнением по Шуру </font> блока  $A_{11}$.
# * (4 pts) Используя свойства дополнения по Шуру докажите, что
#
# $$\det(X+AB) = \det(X)\det(I+BX^{-1}A), $$
#
# - Пусть $Y = \begin{pmatrix} X & A \\ -B & I \end{pmatrix}$.   Тогда  её определитель - $ \operatorname{det} Y=\operatorname{det}(X) \operatorname{det}\left(I+B X^{-1} A\right)=\operatorname{det}(X+A B).$
#
#
# где $X$ невырожденная квадратная матрица.
# * (4 pts) Пусть матрица $F \in \mathbb{R}^{m \times n}$ и $G \in \mathbb{R}^{n \times m}$. Докажите, что
#
# $$\det(I_m - FG) = \det(I_n - GF).$$

# %%
# Your solution is here

# %% [markdown]
# ## Задача 3:  QR разложение (27 pts)
#
# - (5 pts) Реализуйте метод Грама-Шмидта для вычисления QR разложения. На вход подаётся прямоугольная матрица, функция возвращает матрицы ```Q``` и ```R``` из QR разложения. Прототип приведён ниже и не должен изменяться

# %%
# INPUT : rectangular matrix A
# OUTPUT: matrices Q - orthogonal and R - upper triangular such that A = QR
def gram_schmidt_qr(A):
    Q = np.asarray(A, dtype=float)
    Anp = np.asarray(A)
    for i in range(Q.shape[1]):
        current_column = Anp[:, i]
        for j in range(i):
            column = Q[:, j]
            Q[:, i] = Q[:, i] - column.T.dot(current_column) / (column.T.dot(column)) * column
    for i in range(Q.shape[1]):
        Q[:, i] = Q[:, i] / np.sqrt(Q[:, i].T.dot(Q[:, i]))
    return Q, Q.T.dot(Anp)

# %% [markdown]
# - (5 pts) Реализуйте модифицированный метод Грама-Шмидта для вычисления QR разложения. На вход подаётся прямоугольная матрица, функция возвращает матрицы Q и R из QR разложения. Прототип приведён ниже и не должен изменяться

# %%
# INPUT : rectangular matrix A
# OUTPUT: matrices Q - orthogonal and R - upper triangular such that A = QR
def modified_gram_schmidt_qr(A): # 5 pts
    (n_rows, n_cols) = np.shape(A)
    Q = np.empty([n_rows, n_cols], dtype=A.dtype)
    column = 0
    for a in A.T:
        q = np.copy(a)
        for i in range(0, column):
            Rij = np.dot(q, Q[:,i])
            q = q - Rij*Q[:,i]
        Rjj = np.linalg.norm(q, ord=2)

        Q[:,column] = q/Rjj
        column = column + 1
        
    R = np.dot(Q.T, A)
    return Q, R

# %% [markdown]
# - (7 pts) Реализуйте алгоритм вычисления QR разложения, основанный на преобразованиях Хаусхолдера. На вход подаётся прямоугольная матрица, функция возвращает матрицы Q и R из QR разложения. Прототип приведён ниже и не должен изменяться. Обратите внимание на эффективность реализации операции умножения матриц Хаусхолдера для получения матрицы ```Q```.

# %%
# INPUT : rectangular matrix A
# OUTPUT: matrices Q - orthogonal and R - upper triangular such that A=QR
def householder_qr(A): # 7 pts
    def  household(a):
        n_rows = a.shape[0]
        a_sign = np.sign(a[0])
        v = a / (a[0] + (a_sign if a_sign != 0 else 1)*np.linalg.norm(a) )
        v[0] = 1
        H = np.eye(n_rows)
        H -= (2 / np.dot(v, v)) * np.dot(v[:, None], v[None, :])
        return H

    n_rows, n_cols = A.shape
    Q = np.eye(n_rows)
    R = np.copy(A)
    for i in range(n_cols - (n_rows == n_cols)):
        H = np.eye(n_rows)
        H[i:, i:] = household(R[i:, i])
        Q = np.dot(Q, H)
        R = np.dot(H, R)
    return Q, R

# %% [markdown]
# - (2 pts) Сгенерируйте квадратную [матрицу Вандермонда](https://en.wikipedia.org/wiki/Vandermonde_matrix) $V\in\mathbb{R}^{n\times n},\ n = 20$ для вектора $x$: ```x = np.linspace(0,1,n)``` и вычислите QR разложение этой матрицы с помощью каждого из трёх реализованных вами алгоритмов. Вычислите насколько столбцы матрицы $Q$ ортогональны, то есть величину $\|Q^{\top}Q - I\|_2$. Объясните полученный результат.
#
# - (3 pts) Изучите как скорость работы каждого из алгоритмов вычисления QR разложения зависит от числа строк и столбцов матрицы, для которой вычисляется QR разложение. Постройте два графика: на одном покажите зависимость времени вычисления от числа строк при фиксированном числе столбцов, а на другом, наоборот, зависимость времени вычисления от числа столбцов при неизменном числе строк. Выберите диапазоны изменения количества строк и столбцов такими, чтобы можно было увидеть асимптотическую скорость работы для больших матриц.
#
# - (5 pts) Пусть дано QR разложение матрицы $A$ размера $m \times n, \; m > n$. К матрице $A$ добавили ещё одну строку после последней, то есть теперь есть матрица $\hat{A} = \begin{bmatrix} A \\ a \end{bmatrix}$ размера $(m+1) \times n$. Покажите, как найти QR разложение матрицы $\hat{A}$, используя QR разложения матрицы $A$. Сравните асимптотические сложности предложенного вами способа и метода, который не использует QR разложение матрицы $A$. Также экспериментально покажите, как время работы этих двух методов зависит от размерности по числу строк и столбцов матрицы.

# %%
from timeit import default_timer as timer
import matplotlib.pyplot as plt
# %matplotlib inline

n = 20
x = np.linspace(0, 1, n)
A = np.vander(x, n)
I = np.identity(n)

Q, R = gram_schmidt_qr(A)
print( 'QQ.т-I для метода Грамма-Шмидта: ', np.linalg.norm(np.dot(Q.T,Q)-I))
Q, R = modified_gram_schmidt_qr(A)
print(  'QQ.т-I для метода модифицированного Грамма-Шмидта: ', np.linalg.norm(np.dot(Q.T,Q)-I))
Q, R = householder_qr(A)
print(  'QQ.т-I для метода Хаусхолдера: ', np.linalg.norm(np.dot(Q.T,Q)-I))
Q, R = np.linalg.qr(A)
print(   'QQ.т-I для функции numpy: ', np.linalg.norm(np.dot(Q.T,Q)-I))

n_cols = 100
gram_schmidt = []
modified_gram_schmidt = []
householder = []
standard = []
x = []

for n_rows in range(n_cols, 5*n_cols, 100):
    x.append(n_rows)
    A = np.random.rand(n_rows, n_cols)
    start = timer()
    Q, R = gram_schmidt_qr(A)
    end = timer()
    gram_schmidt.append(end-start)
    start = timer()
    Q, R = modified_gram_schmidt_qr(A)
    end = timer()
    modified_gram_schmidt.append(end-start)
    start = timer()
    Q, R = householder_qr(A)
    end = timer()
    householder.append(end-start)
    start = timer()
    Q, R = np.linalg.qr(A)
    end = timer()
    standard.append(end-start)

fig, ax = plt.subplots()
ax.plot(x,gram_schmidt, 'b', label='Gram_schmidt')
ax.plot(x,modified_gram_schmidt, 'r', label='Modified_Gram_schmidt')
ax.plot(x,householder, 'g', label='Householder')
ax.plot(x,standard, 'y', label='Numpy function')
ax.grid()
plt.legend(('Gram_schmidt', 'Modified_Gram_schmidt', 'Householder', 'Numpy function'))
plt.xlabel("Number of rows")
plt.ylabel('Time elapsed')
plt.title('Fixed 100 columns')
plt.show()


n_rows = 200
gram_schmidt = []
modified_gram_schmidt = []
householder = []
standard = []
x = []


for n_cols in range( int(n_rows/5), n_rows, 100):
    x.append(n_cols)
    A = np.random.rand(n_rows, n_cols)
    start = timer()
    Q, R = gram_schmidt_qr(A)
    end = timer()
    gram_schmidt.append(end-start)
    start = timer()
    Q, R = modified_gram_schmidt_qr(A)
    end = timer()
    modified_gram_schmidt.append(end-start)
    start = timer()
    Q, R = householder_qr(A)
    end = timer()
    householder.append(end-start)
    start = timer()
    Q, R = np.linalg.qr(A)
    end = timer()
    standard.append(end-start)

fig, ax = plt.subplots()
ax.plot(x,gram_schmidt, 'b', label='Gram_schmidt')
ax.plot(x,modified_gram_schmidt, 'r', label='Modified_Gram_schmidt')
ax.plot(x,householder, 'g', label='Householder')
ax.plot(x,standard, 'y', label='Numpy function')
ax.grid()
plt.legend(('Gram_schmidt', 'Modified_Gram_schmidt', 'Householder', 'Numpy function'))
plt.xlabel("Number of columns")
plt.ylabel('Time elapsed')
plt.title('Fixed 200 rows')
plt.show()
# Out:
# QQ.т-I для метода Грамма-Шмидта:  0.2516758968411597
# QQ.т-I для метода модифицированного Грамма-Шмидта:  1.0205172202203093e-15
# QQ.т-I для метода Хаусхолдера:  3.633563573922019e-15
# QQ.т-I для функции numpy:  1.914751022608572e-15

# %% [markdown]
# ## Задача 4. Сжатие полносвязных слоёв в нейросети (30 pts)
#
# В этой задаче вам предлагается исследовать, как изменится точность предсказания нейросети, которая классифицирует изображения, если вместо полносвязных слоёв использовать их сжатое представление, полученное с помощью SVD. Результатом решения этой задачи должен быть график зависимости точности классификации на тестовой выборке от количества параметров нейронной сети.

# %% [markdown]
# #### Сначала скачаем данные CIFAR10

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./

# %% [markdown]
# #### Посмотрим, как выглядят изображения

# %%
# %matplotlib inline

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
#  bird horse  ship  bird truck plane  frog   dog

# %% [markdown]
# ### Архитектура нейронной сети
#
# Для простоты и демонстрации принципа сжатия слоёв нейронных сетей рассмотрим архитектуру, состоящую только из полносвязных слоёв (то есть линейных преобразований) и стандартных ReLU-нелинейностей. Опять же для наглядности выбрали размерность 1000 для полносвязных слоёв.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.fc2 = nn.Linear(1000, 1000)
        self.fc3 = nn.Linear(1000, 1000)
        self.fc4 = nn.Linear(1000, 1000)
        self.fc5 = nn.Linear(1000, 1000)
        self.fc6 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)

        y = self.fc2(x)
        y = self.ReLU(y)
        y = self.fc3(y)

        x1 = self.ReLU(y + x)

        
        y1 = self.fc4(x1)
        y1 = self.ReLU(y1)
        y1 = self.fc5(y1)

        x2 = self.ReLU(x1 + y1)

        z = self.fc6(x2)
        return F.log_softmax(z, dim=1)

# %% [markdown]
# #### Функции для обучения и тестирования результата после каждого прохождения всех данных

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %% [markdown]
# ### Зададим параметры обучения и вывода промежуточных результатов

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ### Запускаем обучение с помощью метода оптимизации [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document)
# Если у вас не очень мощный ноутбук, то придётся подождать некоторое время.

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.334021
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.845485
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.658071
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.445051
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.628521
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.689589
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.668602
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.620787
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.387801
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.579421
#
# Test set: Average loss: 1.4580, Accuracy: 4805/10000 (48%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.372154
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.330236
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.428550
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.287245
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.451550
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.374985
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.434982
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.251147
# Train Epoch: 2 [40000/50000 (80%)]	Loss: 1.376482
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 1.528811
#
# Test set: Average loss: 1.3698, Accuracy: 5110/10000 (51%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.290449
# Train Epoch: 3 [5000/50000 (10%)]	Loss: 1.124050
# Train Epoch: 3 [10000/50000 (20%)]	Loss: 1.204846
# Train Epoch: 3 [15000/50000 (30%)]	Loss: 1.187136
# Train Epoch: 3 [20000/50000 (40%)]	Loss: 1.249903
# Train Epoch: 3 [25000/50000 (50%)]	Loss: 1.326457
# Train Epoch: 3 [30000/50000 (60%)]	Loss: 1.238008
# Train Epoch: 3 [35000/50000 (70%)]	Loss: 1.321646
# Train Epoch: 3 [40000/50000 (80%)]	Loss: 1.123159
# Train Epoch: 3 [45000/50000 (90%)]	Loss: 1.397764
#
# Test set: Average loss: 1.2995, Accuracy: 5436/10000 (54%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.144246
# Train Epoch: 4 [5000/50000 (10%)]	Loss: 1.077479
# Train Epoch: 4 [10000/50000 (20%)]	Loss: 1.113723
# Train Epoch: 4 [15000/50000 (30%)]	Loss: 1.266126
# Train Epoch: 4 [20000/50000 (40%)]	Loss: 1.087270
# Train Epoch: 4 [25000/50000 (50%)]	Loss: 1.048373
# Train Epoch: 4 [30000/50000 (60%)]	Loss: 1.181505
# Train Epoch: 4 [35000/50000 (70%)]	Loss: 1.021257
# Train Epoch: 4 [40000/50000 (80%)]	Loss: 0.971394
# Train Epoch: 4 [45000/50000 (90%)]	Loss: 1.043038
#
# Test set: Average loss: 1.2902, Accuracy: 5497/10000 (55%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.884578
# Train Epoch: 5 [5000/50000 (10%)]	Loss: 0.853948
# Train Epoch: 5 [10000/50000 (20%)]	Loss: 0.999117
# Train Epoch: 5 [15000/50000 (30%)]	Loss: 1.111078
# Train Epoch: 5 [20000/50000 (40%)]	Loss: 0.946634
# Train Epoch: 5 [25000/50000 (50%)]	Loss: 1.015476
# Train Epoch: 5 [30000/50000 (60%)]	Loss: 1.079613
# Train Epoch: 5 [35000/50000 (70%)]	Loss: 1.221718
# Train Epoch: 5 [40000/50000 (80%)]	Loss: 1.123303
# Train Epoch: 5 [45000/50000 (90%)]	Loss: 0.958129
#
# Test set: Average loss: 1.2741, Accuracy: 5572/10000 (56%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.778191
# Train Epoch: 6 [5000/50000 (10%)]	Loss: 0.866420
# Train Epoch: 6 [10000/50000 (20%)]	Loss: 0.870460
# Train Epoch: 6 [15000/50000 (30%)]	Loss: 0.936886
# Train Epoch: 6 [20000/50000 (40%)]	Loss: 0.993453
# Train Epoch: 6 [25000/50000 (50%)]	Loss: 0.836031
# Train Epoch: 6 [30000/50000 (60%)]	Loss: 0.995852
# Train Epoch: 6 [35000/50000 (70%)]	Loss: 0.913193
# Train Epoch: 6 [40000/50000 (80%)]	Loss: 0.929838
# Train Epoch: 6 [45000/50000 (90%)]	Loss: 1.062196
#
# Test set: Average loss: 1.3031, Accuracy: 5581/10000 (56%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.777434
# Train Epoch: 7 [5000/50000 (10%)]	Loss: 0.835686
# Train Epoch: 7 [10000/50000 (20%)]	Loss: 0.568380
# Train Epoch: 7 [15000/50000 (30%)]	Loss: 0.711480
# Train Epoch: 7 [20000/50000 (40%)]	Loss: 0.784006
# Train Epoch: 7 [25000/50000 (50%)]	Loss: 0.749222
# Train Epoch: 7 [30000/50000 (60%)]	Loss: 0.939797
# Train Epoch: 7 [35000/50000 (70%)]	Loss: 1.055626
# Train Epoch: 7 [40000/50000 (80%)]	Loss: 0.824304
# Train Epoch: 7 [45000/50000 (90%)]	Loss: 0.877225
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)

# %% [markdown]
# - (3 pts) Вычислите SVD для матрицы $1000 \times 1000$, которая соответствует любому слою подходящего размера обученной нейросети. Покажите на графике убывание сингулярных чисел. Какой вывод можно сделать?
# - (12 pts) Создайте модель (аналогично классу ```Net```), которая на вход будет принимать экземпляр класса ```Net```, ранг $r > 0$ и список индексов слоёв, веса которых будут сжиматься. Эта модель должна сжимать некоторые полносвязные слои (индексы которых переданы на вход) с помощью SVD разложения, из которого берутся только первые $r$ компонент. Также функция ```forward``` должна быть эффективно реализована с использованием сжатого представления полносвязных слоёв, а в остальном полностью повторять эту же функцию для несжатой обученной сети.
# - (5 pts) Постройте зависимость точности предсказания на тестовой выборе от количества параметров, которое необходимо для этого. Это количество, очевидно, некоторым образом зависит от заданного ранга сжатия $r$. Также постройте зависимость времени вычисления от ранга сжатия. Объясните полученные результаты. Для вычисления времени используйте [%timeit](https://docs.python.org/3.6/library/timeit.html) c необходимыми параметрами (примеры смотрите в лекции)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fc2_u, fc2_s, fc2_v = np.linalg.svd(model.fc2.weight.data)
fc3_u, fc3_s, fc3_v = np.linalg.svd(model.fc3.weight.data)
fc4_u, fc4_s, fc4_v = np.linalg.svd(model.fc4.weight.data)
fc5_u, fc5_s, fc5_v = np.linalg.svd(model.fc5.weight.data)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)


ax1.plot(fc2_s / fc2_s[0])
ax2.plot(fc3_s / fc3_s[0])
ax3.plot(fc4_s / fc4_s[0])
ax4.plot(fc5_s / fc5_s[0])


plt.show()

# %%
class ModifiedNet(nn.Module):
    def __init__(self, base, r ):
        super(ModifiedNet, self).__init__()

        layers = [model.fc1, model.fc2, model.fc3, model.fc4, model.fc5, model.fc6]
        self.n_layers = len(layers)
        self.u = [[]] * self.n_layers
        self.s = [[]] * self.n_layers
        self.v = [[]] * self.n_layers
        self.bias = [[]] * self.n_layers
        for i, f in enumerate(layers):
            u, s, v = torch.svd(f.weight.data)
            self.u[i] = torch.nn.parameter.Parameter(u[:, :r])
            self.register_parameter('U' + str(i), self.u[i])
            self.s[i] = torch.nn.parameter.Parameter(s[:r])
            self.register_parameter('S' + str(i), self.s[i])
            self.v[i] = torch.nn.parameter.Parameter(v[:, :r])
            self.register_parameter('V' + str(i), self.v[i])
            self.bias[i] = torch.nn.parameter.Parameter(f.bias)
        self.ReLU = nn.ReLU()
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = x.view(-1, 3 * 32*32)
        for i in range(self.n_layers):
            x = torch.mm(torch.mm(x, self.v[i]), (self.u[i] * self.s[i][None, :]).t())
            x += self.bias[i]
            x = self.ReLU(x)
        return F.log_softmax(x, dim=1)

# %%
from timeit import default_timer as timer

time = []
accuracy = []
for r in range(20,1020,50):
    print('net with r=',r)
    start = timer()
    new_model = ModifiedNet(model, r)
    acc = test(model, test_loader)
    end = timer()
    accuracy.append(acc)
    time.append(end-start)
# Out:
# net with r= 20
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 70
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 120
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 170
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 220
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 270
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 320
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 370
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 420
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 470
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 520
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 570
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 620
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 670
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 720
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 770
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 820
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 870
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 920
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)
#
# net with r= 970
#
# Test set: Average loss: 1.3450, Accuracy: 5512/10000 (55%)

# %%
# %matplotlib inline
plt.plot(list(range(20,1020,50)), time)
plt.xlabel("r")
plt.ylabel('Time elapsed')
plt.title('Time')
plt.show()

# %%
# %matplotlib inline
plt.plot(list(range(20,1020,50)), accuracy)
plt.xlabel("r")
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.show()

# %% [markdown]
# - Сингулярные числа  убывают, что позволяет говорить о том, что SVD разложение позволит уменьшить количество весов
# -
# При уменьшении $r$ уменьшается общее количество параметров и уменьшается время работы
#
# - точность не особо зависит от r

# %% [markdown]
# ### Fine-tuning
#
# - (10 pts) Поскольку в вашей модели, которая использует сжатое представление линейных слоёв, параметрами являются матрицы, полученные из SVD соответствующих линейных слоёв, то их также можно оптимизировать. Эта процедура называется fine-tuning. Предлагается провести обучение этих матриц в течение нескольких эпох (от 1 до 5 будет достаточно) и сравнить насколько выросло качество по сравнению с первоначальными значениями. Покажите значения точности на тестовой выборки и объясните полученные результаты.

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)
new_model = ModifiedNet(model, 800)
n_epoch = 3
for epoch in range(1, n_epoch + 1):
    train(new_model, train_loader, optimizer, epoch)
    test (new_model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 1.949246
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.922056
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.941824
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.968327
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.947219
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.971875
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.892902
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.948120
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.950996
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.924490
#
# Test set: Average loss: 2.0316, Accuracy: 3484/10000 (35%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.936054
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.930799
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.947423
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.920427
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.904271
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.909032
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.947860
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.990088
# Train Epoch: 2 [40000/50000 (80%)]	Loss: 1.926190
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 1.937041
#
# Test set: Average loss: 2.0316, Accuracy: 3484/10000 (35%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.864326
# Train Epoch: 3 [5000/50000 (10%)]	Loss: 1.844620
# Train Epoch: 3 [10000/50000 (20%)]	Loss: 1.931734
# Train Epoch: 3 [15000/50000 (30%)]	Loss: 1.920169
# Train Epoch: 3 [20000/50000 (40%)]	Loss: 1.953501
# Train Epoch: 3 [25000/50000 (50%)]	Loss: 1.965493
# Train Epoch: 3 [30000/50000 (60%)]	Loss: 1.879835
# Train Epoch: 3 [35000/50000 (70%)]	Loss: 1.799476
# Train Epoch: 3 [40000/50000 (80%)]	Loss: 1.957809
# Train Epoch: 3 [45000/50000 (90%)]	Loss: 1.867505
#
# Test set: Average loss: 2.0316, Accuracy: 3484/10000 (35%)
